# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import urllib
import pandas as pd
import feedparser
from pprint import pprint
import csv
import time
from datetime import datetime
import telegram
import telepot
import requests

key = '5937284055:AAGDgus64D-HwMpOzdpMncqXufer2xIb0D8'
telegram_group_id = 'Chiron_partners'

# 리스트가 길어서 보기가 불편하면 Alt + z 를 누르세요!!
companies = ['비보존제약', '텔콘RF제약', '우진', '유니셈', '한국캐피탈', '부산주공', 'NK맥스', '뉴인텍', '에이엔피', '비보존제약', '대유플러스', '갤럭시아머니트리', '비엠티',  '폴라리스우노', '미스터블루', '와이제이엠게임즈', '엔시트론', '에이치엔비디자인', '키이스트', '이엠앤아이', '폴라리스세원', '폴라리스오피스', '네오펙트', '앱코', '웰바이오텍', '에스티큐브', 'WSI', '비트나인', '경동제약', '에이티세미콘',  '엑서지21']

def news_release():
    
    while True:
        
        class BreakIt(Exception): pass
        
        for company in companies:

            html = urlopen('https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=1&photo=0&field=0&pd=0&ds=&de=&docid=&related=0&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so%3Add%2Cp%3Aall&is_sug_officeid=0'.format(urllib.parse.quote(company)))
            bs_obj = BeautifulSoup(html, 'html.parser')
            name_list = bs_obj.find_all('div', {'class':'api_save_group _keep_wrap'})
            list_URL = [ child.get('data-url') for name in name_list for child in name.findChildren('a', recursive=False) ]

            try:
                for url in list_URL[0:5]:
                    with open('./news_release_URL.csv', 'r', encoding='utf-8-sig') as f: 
                        reader = csv.reader(f, delimiter=',', quoting=csv.QUOTE_NONE) 
                        for line in reader:
                            line = ''.join(line)
                            if line == url:
                                print(company, '중복입니다!', sep=': ')
                                raise BreakIt
                            else:
                                continue  #Loop를 계속 돌려서 중복이 모든 line에 없으면 아래로 이동
                                
                        message = '[ {} ]\n{}'.format(company, url)

                        telegram_api_url = f'https://api.telegram.org/bot{key}/sendMessage?chat_id=@{telegram_group_id}&text={message}'
                        tel_resp = requests.get(telegram_api_url)
                        print(tel_resp.status_code)
                        
                        if tel_resp.status_code == 200:
                            print(message)
                        else:
                            print(company, 'Error')

                        print('항목 추가 완료')
                        time.sleep(1)

                    with open('./news_release_URL.csv', 'a', encoding='utf-8-sig') as f: 
                        f.write(url + '\n')
                        f.close()


            except BreakIt:
                pass

        print(datetime.now())
        print('----------------------------------------------------------')
        time.sleep(300)

for i in range(1, 100):
    try:
        news_release()
    except Exception as e:
        print(e)
        print('restarting')
        continue
    else:
        break
# Out:
# 200
# [ 비보존제약 ]
# http://www.inews24.com/view/1581080
# 항목 추가 완료
# 200
# [ 비보존제약 ]
# http://www.newsis.com/view/?id=NISX20230331_0002249648&cID=15001&pID=15000
# 항목 추가 완료
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 200
# [ 우진 ]
# http://www.newsmaker.or.kr/news/articleView.html?idxno=138734
# 항목 추가 완료
# 200
# [ 우진 ]
# https://news.mtn.co.kr/news-detail/2023033117102119712
# 항목 추가 완료
# 200
# [ 우진 ]
# https://www.gukjenews.com/news/articleView.html?idxno=2686620
# 항목 추가 완료
# 200
# [ 우진 ]
# https://idsn.co.kr/news/view/1065594606926304
# 항목 추가 완료
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 200
# [ 한국캐피탈 ]
# http://news.mt.co.kr/mtview.php?no=2023033111434266490
# 항목 추가 완료
# 200
# [ 한국캐피탈 ]
# https://www.ngetnews.com/news/articleView.html?idxno=416982
# 항목 추가 완료
# 200
# [ 한국캐피탈 ]
# https://www.dailian.co.kr/news/view/1218285/?sc=Naver
# 항목 추가 완료
# 한국캐피탈: 중복입니다!
# 200
# [ 부산주공 ]
# https://www.thekpm.com/news/articleView.html?idxno=151190
# 항목 추가 완료
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 200
# [ 엔시트론 ]
# https://www.pinpointnews.co.kr/news/articleView.html?idxno=186612
# 항목 추가 완료
# 200
# [ 엔시트론 ]
# https://view.asiae.co.kr/article/2023033117222624957
# 항목 추가 완료
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 200
# [ 에스티큐브 ]
# http://www.lcnews.co.kr/news/articleView.html?idxno=48311
# 항목 추가 완료
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 17:39:30.023574
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 17:44:41.334476
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 17:49:50.296609
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 200
# [ 미스터블루 ]
# http://www.topstarnews.net/news/articleView.html?idxno=15316500
# 항목 추가 완료
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 17:55:01.076741
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 200
# [ 우진 ]
# https://www.thekpm.com/news/articleView.html?idxno=151188
# 항목 추가 완료
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:00:12.386418
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 200
# [ 엔시트론 ]
# http://www.ntoday.co.kr/news/articleView.html?idxno=96886
# 항목 추가 완료
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:05:23.510657
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:10:33.360466
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:15:43.178708
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 200
# [ 대유플러스 ]
# https://news.jtbc.co.kr/article/article.aspx?news_id=NB12120562
# 항목 추가 완료
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:20:56.762274
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:26:06.087277
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:31:16.069886
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:36:26.131188
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-03-31 18:41:36.298508
# ----------------------------------------------------------
# 200
# [ 비보존제약 ]
# http://www.newsis.com/view/?id=NISX20230331_0002249617&cID=10403&pID=15000
# 항목 추가 완료
# 200
# [ 비보존제약 ]
# https://medicalworldnews.co.kr/news/view.php?idx=1510954750
# 항목 추가 완료
# 200
# [ 비보존제약 ]
# http://www.newswell.co.kr/news/articleView.html?idxno=8026
# 항목 추가 완료
# 200
# [ 비보존제약 ]
# https://www.tfmedia.co.kr/news/article.html?no=141921
# 항목 추가 완료
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 200
# [ 우진 ]
# http://www.cooknchefnews.com/news/view/1065577343583182
# 항목 추가 완료
# 200
# [ 우진 ]
# http://www.newsworker.co.kr/news/articleView.html?idxno=199152
# 항목 추가 완료
# 200
# [ 우진 ]
# http://www.ccnnews.co.kr/news/articleView.html?idxno=290044
# 항목 추가 완료
# 200
# [ 우진 ]
# https://www.pinpointnews.co.kr/news/articleView.html?idxno=186608
# 항목 추가 완료
# 200
# [ 우진 ]
# https://www.newscj.com/news/articleView.html?idxno=3014185
# 항목 추가 완료
# 200
# [ 유니셈 ]
# http://news.heraldcorp.com/view.php?ud=20230331000714
# 항목 추가 완료
# 200
# [ 유니셈 ]
# https://www.thekpm.com/news/articleView.html?idxno=151196
# 항목 추가 완료
# 유니셈: 중복입니다!
# 200
# [ 한국캐피탈 ]
# https://biz.chosun.com/stock/stock_general/2023/04/01/W25AIUBMGZFIDJDTL2O6AS45BU/?utm_source=naver&utm_medium=original&utm_campaign=biz
# 항목 추가 완료
# 200
# [ 한국캐피탈 ]
# https://www.dailian.co.kr/news/view/1218391/?sc=Naver
# 항목 추가 완료
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 200
# [ 뉴인텍 ]
# https://www.thekpm.com/news/articleView.html?idxno=151194
# 항목 추가 완료
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 200
# [ 대유플러스 ]
# https://www.ytn.co.kr/_ln/0101_202304011024562563
# 항목 추가 완료
# 대유플러스: 중복입니다!
# 200
# [ 갤럭시아머니트리 ]
# http://www.lawissue.co.kr/view.php?ud=202304011024063348204ead0791_12
# 항목 추가 완료
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 200
# [ 미스터블루 ]
# https://www.nspna.com/news/?mode=view&newsid=629320
# 항목 추가 완료
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 200
# [ 엔시트론 ]
# https://www.tfmedia.co.kr/news/article.html?no=141926
# 항목 추가 완료
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 200
# [ 키이스트 ]
# https://www.pinpointnews.co.kr/news/articleView.html?idxno=186658
# 항목 추가 완료
# 키이스트: 중복입니다!
# 200
# [ 이엠앤아이 ]
# https://www.hankyung.com/finance/article/202303316815i
# 항목 추가 완료
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 429
# 네오펙트 Error
# 항목 추가 완료
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 429
# 에스티큐브 Error
# 항목 추가 완료
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:14:16.678623
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:19:24.276067
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:24:32.263021
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:29:40.478197
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:34:48.360956
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:39:56.322943
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:45:04.728090
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 200
# [ 갤럭시아머니트리 ]
# https://www.cbci.co.kr/news/articleView.html?idxno=439452
# 항목 추가 완료
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:50:15.151203
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 11:55:23.687988
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 12:00:32.011152
# ----------------------------------------------------------
# 비보존제약: 중복입니다!
# 텔콘RF제약: 중복입니다!
# 우진: 중복입니다!
# 유니셈: 중복입니다!
# 한국캐피탈: 중복입니다!
# 부산주공: 중복입니다!
# NK맥스: 중복입니다!
# 뉴인텍: 중복입니다!
# 에이엔피: 중복입니다!
# 비보존제약: 중복입니다!
# 대유플러스: 중복입니다!
# 갤럭시아머니트리: 중복입니다!
# 비엠티: 중복입니다!
# 폴라리스우노: 중복입니다!
# 미스터블루: 중복입니다!
# 와이제이엠게임즈: 중복입니다!
# 엔시트론: 중복입니다!
# 에이치엔비디자인: 중복입니다!
# 키이스트: 중복입니다!
# 이엠앤아이: 중복입니다!
# 폴라리스세원: 중복입니다!
# 폴라리스오피스: 중복입니다!
# 네오펙트: 중복입니다!
# 앱코: 중복입니다!
# 웰바이오텍: 중복입니다!
# 에스티큐브: 중복입니다!
# WSI: 중복입니다!
# 비트나인: 중복입니다!
# 경동제약: 중복입니다!
# 에이티세미콘: 중복입니다!
# 엑서지21: 중복입니다!
# 2023-04-01 12:05:40.503557
# ----------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\김한솔\projects\stock-calendar\news_release.ipynb 셀 1 in <cell line: 71>()
#      <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=70'>71</a> for i in range(1, 100):
#      <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=71'>72</a>     try:
# ---> <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=72'>73</a>         news_release()
#      <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=73'>74</a>     except Exception as e:
#      <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=74'>75</a>         print(e)
#
# c:\김한솔\projects\stock-calendar\news_release.ipynb 셀 1 in news_release()
#      <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a> print(datetime.now())
#      <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=67'>68</a> print('----------------------------------------------------------')
# ---> <a href='vscode-notebook-cell:/c%3A/%EA%B9%80%ED%95%9C%EC%86%94/projects/stock-calendar/news_release.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a> time.sleep(300)
#
# KeyboardInterrupt:
